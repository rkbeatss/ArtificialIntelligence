# %% [markdown]
# # Notebook 2 - Simulated annealing for the TSP

# %% [markdown]
# CSI4106 Artificial Intelligence
# Fall 2019
# Prepared by Caroline Barrière and Julian Templeton

# %% [markdown]
# ***INTRODUCTION***:
#
# This homework will allow you to look deeper into one of the randomized searches presented in class, that of *Simulated Annealing*. It is a good example of a *random modification* algorithm, in which we start with a greedy solution, and then make changes and accept the modified solutions with different probabilities given their level of fitness to a cost function.
#
# The application domain for experimenting with *Simulated Annealing* is the traveling salesman problem (TSP), which is a classical problem of scheduling, with optimization on the cost of travel.
#
# The notebook will lead into the **Simulated Annealing** portion after exploring a **greedy approach** and a **randomized greedy approach**.

# %% [markdown]
# ***HOMEWORK***:
# Go through the notebook by running each cell, one at a time.
# Look for **(TO DO)** for the tasks that you need to perform. Do not edit the code outside of the questions which you are asked to answer unless specifically asked. Once you're done, sign the notebook (see the added step at the end), and submit it.
#
# *The notebook will be marked on 20.
# Each **(TO DO)** has a number of points associated with it.*
# ***

# %% [markdown]
# **1. Let's start with a small set of cities.**

# %%
# let's define 5 cities with a label and a (x,y) coordinate
cities = {'A': (0,0), 'B': (1,1), 'C': (0,1), 'D': (-1,1), 'E': (-1,-1)}

# %% [markdown]
# Let's plot the nodes using the *showNodes* method below.
# The packages matplotlib, networkx, and numpy must be installed first.
# To do so, open a command prompt and type **pip install numpy**, **pip install matplotlib**, and also **pip install networkx** (If you are using linux or potentially Mac, you may need to use **pip3** rather than **pip** depending on how you set it up).  After installing the packages, run the cell below. If it does not work, restart the Kernel and run through it again to be able to run the cell.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# small method to show nodes
# provide defaults for figure size (size), as well as x and y axis
def showNodes(nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.Graph()
    for k in nodeDict.keys():
        G.add_node(k, coor=nodeDict.get(k))
    
    pos=nx.get_node_attributes(G,'coor')
    nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %%
# show the cities on a map
showNodes(cities)

# %% [markdown]
# #### 2. Let's find the distances between all cities.
# First, we define a method to calculate the distance between two specific cities, and then a method to find the distances between all pairs of nodes.

# %%
import math

# returns the euclidian distance between two nodes
def dist(node1, node2):
    return round(math.sqrt(math.pow(node1[0] - node2[0], 2) + math.pow(node1[1] - node2[1], 2)), 3)

# %%
# Small test to see the distance
print(dist(cities.get('A'), cities.get('B')))
print(dist(cities.get('A'), cities.get('C')))
# Out:
# 1.414
# 1.0

# %%
# building a dictionary of all pairs or distances
def distDict(nodes):
    distance = {}
    # go through all pairs of nodes
    for k in nodes.keys():
        for m in nodes.keys():
            distance[k,m] = dist(nodes.get(k), nodes.get(m))
    return distance

# %%
# showing the distances between the cities
distances = distDict(cities)
print(distances)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# and the precalculated distances between all nodes
def closestNode(node1_label, otherNodes_Labels, distanceDict):
    # tricky syntax... it creates tuples where the distance is the first element of the tuple
    # and the position in the array is the second element of the tuple
    minDist = min( (distanceDict[node1_label,k], k) for k in otherNodes_Labels)
    # get the second element of the tuple which is the index found
    foundNode = minDist[1]
    return foundNode

# %%
# Testing the closest node
print(closestNode('B', ['C', 'D'], distances))
print(closestNode('D', ['A','D'], distances))
# Out:
# C
# D

# %% [markdown]
# #### 3. Greedy solution first
# Before we can apply *simulated annealing*, we must first find a suboptimal solution that we will refine. The first solution will be a Greedy solution. Only the choice of the starting node is random in this solution, and from there, the algorithm always choses the closest node.

# %%
# greedy solution
import random

def greedy_solution(nodes):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        # find the closestNode
        found_node = closestNode(cur_node, free_list, allDist)
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Test obtaining a greedy solution
gs = greedy_solution(cities)
print(gs)
# Out:
# ['D', 'C', 'A', 'B', 'E']

# %% [markdown]
# #### 4. Showing a path.
# We slightly modify to showNodes method from before, to become showPath, which is now a directed graph.

# %%
# small method to show a path
# it receives an ordered list of nodes e.g. ['B','C','A', 'D', 'E']
# and a dictionary of all the nodes and their positions
def showPath(path, nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.DiGraph()
    for k in path:
        G.add_node(k, pos=nodeDict.get(k))
        
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i + 1]
        G.add_edge(x,y)
        
    pos=nx.get_node_attributes(G,'pos')
    nx.draw(G, pos, with_labels = True, edge_color = 'b', arrows=True)   
    nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %% [markdown]
# **(TO DO) Q1 - 2 marks**
# 1. Select a seed (integer) to use in the cell below
# 2. Run that cell to set the seed (only once)
# 3. Run the tests below the seed declaration repeatedly (just manually run it) until you get two identical results in the same run. Record how many runs it took and the solution found in the answer section below.
# 4. Run the tests below the seed declaration repeatedly (just manually run it) until you get two different results in the same run. Record how many runs it took and the solution found in the answer section below.

# %% [markdown]
# **(ANSWER in this Markdown) Q1**
# Nb of runs needed to generate an identical gs1 and gs2 :  3 runs
# Solution generated for the identical gs1 and gs2 : ['A','C','B','D','E']
#
# Nb of runs needed to generate a different gs1 and gs2 :  1 run
# Solutions generated for the distinct gs1 and gs2 : ['E', 'A', 'C','B','D] and ['A','C','B','D','E']

# %% [markdown]
# Setup the seed:

# %%
# To Do: Place your seed here and run the cell to set/reset it
# random.seed(int)
random.seed(6)

# %% [markdown]
# Let us run a test to visualize two greedy solutions

# %%
# To Do: Need to run this (make no changes) and answer the questions above

# Testing to output the path chosen by the greedy solution
gs1 = greedy_solution(cities)
print(gs1)
showPath(gs1, cities)
gs2 = greedy_solution(cities)
print(gs2)
showPath(gs2, cities)
# Out:
# ['E', 'A', 'C', 'B', 'D']
# ['A', 'C', 'B', 'D', 'E']

# %% [markdown]
# **(TO DO) Q2 - 2 marks**
# Complete the method to find the total length of the path found.

# %%
# (TO DO) totalDistance, which receives a path (list of node labels) and the dictionary of distances
def totalDist(path, distanceDict):
    total = 0
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i+1]
        total += distanceDict[x, y]
    return round(total,3)

# %%
# Test the total distance method
print(totalDist(gs1, distances))
print(totalDist(gs2, distances))
# Out:
# 5.414
# 6.0

# %% [markdown]
# **(TO DO) Q3 - 4 marks**
# Add two more cities (wherever you want within the predefined -2 to +2 axis).  Rerun the full sequence of tasks performed above on the larger set of cities that you will define below: (1) defining the graph (2) showing the points (3) building the distance dictionary, (4) finding two unique greedy solutions, (5) showing the different paths found along with their total distances.

# %%
# (1) Defining a larger set of cities  (add two more)
moreCities = {'A': (0,0), 'B': (1,1), 'C': (0,1), 'D': (-1,1), 'E': (-1,-1), 'F':(0,-1), 'G':(-1,0)}
# (2) Show the points
showNodes(moreCities)
# (3) Build the distance dictionary
distancesM = distDict(moreCities)
print(distancesM)
# (4) Find two unique greedy solutions 
gsm1 = greedy_solution(moreCities)
gsm2 = greedy_solution(moreCities)
# (5) Show the two unique paths found above along with their total distances
print('\n')
print("Path: {}, Total Distance: {}".format(gsm1, totalDist(gsm1, distancesM)))
showPath(gsm1, moreCities)
print("Path: {}, Total Distance: {}".format(gsm2, totalDist(gsm2,distancesM)))
showPath(gsm2, moreCities)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('A', 'F'): 1.0, ('A', 'G'): 1.0, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('B', 'F'): 2.236, ('B', 'G'): 2.236, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('C', 'F'): 2.0, ('C', 'G'): 1.414, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('D', 'F'): 2.236, ('D', 'G'): 1.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0, ('E', 'F'): 1.0, ('E', 'G'): 1.0, ('F', 'A'): 1.0, ('F', 'B'): 2.236, ('F', 'C'): 2.0, ('F', 'D'): 2.236, ('F', 'E'): 1.0, ('F', 'F'): 0.0, ('F', 'G'): 1.414, ('G', 'A'): 1.0, ('G', 'B'): 2.236, ('G', 'C'): 1.414, ('G', 'D'): 1.0, ('G', 'E'): 1.0, ('G', 'F'): 1.414, ('G', 'G'): 0.0}
#
#
# Path: ['D', 'C', 'A', 'F', 'E', 'G', 'B'], Total Distance: 7.236
# Path: ['G', 'A', 'C', 'B', 'D', 'E', 'F'], Total Distance: 8.0

# %% [markdown]
# **5. Randomized Greedy - Setup**
#
# Before we create our Randomized Greedy solution, we will define a new function called kClosestNodes that will return the k-closest nodes to a given node.

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# the precalculated distances between all nodes, and k for how many to return
# The function then outputs a list of the k-closest nodes, where the
# first is the closest and the kth is the kth-closest
def kClosestNodes(node1_label, otherNodes_Labels, distanceDict, k):
    kClosest = []
    # Create a sorted distance list based on the values from the distance dictionary
    # This has the form [((node_1, node_2),value_1), ..., ((node_n, node_n), value_n)]
    sortedDistances = sorted(distanceDict.items(), key=lambda keyPair: keyPair[1])
    # Iterate through the sorted distance list to find our k min distances
    # from node1_label
    for key, value in sortedDistances:
        if (k > 0 and key[0] == node1_label and key[1] in otherNodes_Labels):
            '''if k is greater than 0 and if the given node1 is the first key and the next key is in the given list
            then we have found one closest one (since its sorted) then decrement k to find the number of closest
            nodes according to user input
            '''
            k -= 1
            kClosest.append(key[1])
    return kClosest

# %%
# Example usage
# View the distance dictionary to verify correctness when finding the closest nodes
# to node B in cities
print(distances)
# Find the two closest nodes to the node B in cities (using its distance dictionary)
kClosestNodes('B', ['A', 'C', 'D', 'E'], distances, 3)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}
# ['C', 'A', 'D']

# %% [markdown]
# **6. Randomized Greedy**
#
# Next you will find another suboptimal solution that we will refine. This second solution will be a Randomized Greedy solution.

# %% [markdown]
# **(TO DO) Q4 - 5 marks**
# The Randomized Greedy solution that you will create still selects a random first node, but should now pick randomly among the k closest nodes available given a probability distribution (rather than the closest node).
#
# For example, if you found the five closest nodes when looking for which to add next, you would randomly choose one of them where the closest nodes would have a higher probability of being chosen then the nodes that are not as close.
#
# The probability distribution for a set of node distances is given by the function *normalize* below and finding the k-closest nodes is given from the kClosestNodes function above. You must call both of these functions in your solution and follow the general structure defined by the comments.
#
# After finishing the function, add one more test to the tests below with a different value for k

# %%
import random
import numpy as np

# DO NOT EDIT THIS FUNCTION
# nodeFrom is the node we start at, nodesTo is a list of nodes
# that nodeFrom can go to, and distDict is the dictionary of all
# combinations of distances.
# This provides the probability distribution to be used by
# randomized_greedy_solution
def normalize(nodeFrom, nodesTo, distDict):
    distances = []
    # Here we normalize by 1/distance^2 
    for nodeTo in nodesTo:
        distances.append(1 / distDict[nodeFrom, nodeTo] ** 2)
    sumOfDistances = sum(distances)
    normalizedDistances = [dist / sumOfDistances for dist in distances]
    return normalizedDistances
    
# k represents the number of closest nodes to be returned from the
# function kClosestNodes
def randomized_greedy_solution(nodes, k):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        
        # TO DO START: Complete the algorithm by performing what the comments ask
        
        # Get the closest nodes
        closestNodes = kClosestNodes(cur_node, free_list, allDist, k)
        # Find the normalized distances
        normalizedDistances = normalize(cur_node, closestNodes, allDist)
        # Select a random closest node based on the probabilities found by the normalized distances
        # You will use the function np.random.choice(options, list_of_probabilities_for_options)
        # For more information on np.random.choice check out the official documentation:
        #      https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.choice.html#numpy.random.choice
        randomNode = np.random.choice(closestNodes,1, normalizedDistances)
        found_node = randomNode[0] #we know that this list will always contain a single value so we can access it this way
        # Print out the probabilities for each closest node choice (just output both lists saying what they are)
        print("Closest Nodes: {}".format(closestNodes))
        print("Normalized distances: {}".format(normalizedDistances))
        # Print out the closest node selected by the probability distribution with it's probability of being selected
        print("Node selected by probability distribution: {}".format(found_node))
        # TO DO END
        
        # Same as in the Greedy approach
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Testing to output the path chosen by the randomized greedy solution with various k's to the greedy solution
# Run a few times to see how the results differ with the non-deterministic Randomized Greedy solution
# Note that if they start with the same node and k=1 that the results of both will be the same
moreDistances = distDict(moreCities)
print("Greedy Test")
gr = greedy_solution(moreCities)
print(gr)
print(totalDist(gr, moreDistances))
showPath(gr, moreCities)
print("Randomized Greedy Test")
rgs1 = randomized_greedy_solution(moreCities, 1)
print(rgs1)
print(totalDist(rgs1, moreDistances))
showPath(rgs1, moreCities)
print("Randomized Greedy Test")
rgs2 = randomized_greedy_solution(moreCities, 2)
print(rgs2)
print(totalDist(rgs2, moreDistances))
showPath(rgs2, moreCities)
# TO DO: Add one more test randomized_greedy_solution with a different k
rgs3 = randomized_greedy_solution(moreCities, 3)
print(rgs2)
print(totalDist(rgs3,moreDistances))
showPath(rgs3, moreCities)
# Out:
# Greedy Test
# ['C', 'A', 'F', 'E', 'G', 'D', 'B']
# 7.0
# Randomized Greedy Test
# Closest Nodes: ['C']
# Normalized distances: [1.0]
# Node selected by probability distribution: C
# Closest Nodes: ['B']
# Normalized distances: [1.0]
# Node selected by probability distribution: B
# Closest Nodes: ['D']
# Normalized distances: [1.0]
# Node selected by probability distribution: D
# Closest Nodes: ['G']
# Normalized distances: [1.0]
# Node selected by probability distribution: G
# Closest Nodes: ['E']
# Normalized distances: [1.0]
# Node selected by probability distribution: E
# Closest Nodes: ['F']
# Normalized distances: [1.0]
# Node selected by probability distribution: F
# ['A', 'C', 'B', 'D', 'G', 'E', 'F']
# 7.0
# Randomized Greedy Test
# Closest Nodes: ['C', 'F']
# Normalized distances: [0.5, 0.5]
# Node selected by probability distribution: C
# Closest Nodes: ['B', 'D']
# Normalized distances: [0.5, 0.5]
# Node selected by probability distribution: B
# Closest Nodes: ['D', 'F']
# Normalized distances: [0.5555405427027759, 0.44445945729722425]
# Node selected by probability distribution: F
# Closest Nodes: ['E', 'G']
# Normalized distances: [0.6665995420411309, 0.3334004579588691]
# Node selected by probability distribution: E
# Closest Nodes: ['G', 'D']
# Normalized distances: [0.8, 0.2]
# Node selected by probability distribution: G
# Closest Nodes: ['D']
# Normalized distances: [1.0]
# Node selected by probability distribution: D
# ['A', 'C', 'B', 'F', 'E', 'G', 'D']
# 7.236
# Closest Nodes: ['C', 'A', 'D']
# Normalized distances: [0.5713792546677926, 0.2857759316652593, 0.14284481366694815]
# Node selected by probability distribution: C
# Closest Nodes: ['A', 'D', 'G']
# Normalized distances: [0.39997583416153343, 0.39997583416153343, 0.2000483316769332]
# Node selected by probability distribution: A
# Closest Nodes: ['F', 'G', 'D']
# Normalized distances: [0.39997583416153343, 0.39997583416153343, 0.2000483316769332]
# Node selected by probability distribution: D
# Closest Nodes: ['G', 'E', 'F']
# Normalized distances: [0.6896493885196742, 0.17241234712991854, 0.1379382643504073]
# Node selected by probability distribution: G
# Closest Nodes: ['E', 'F']
# Normalized distances: [0.6665995420411309, 0.3334004579588691]
# Node selected by probability distribution: E
# Closest Nodes: ['F']
# Normalized distances: [1.0]
# Node selected by probability distribution: F
# ['A', 'C', 'B', 'F', 'E', 'G', 'D']
# 6.414

# %% [markdown]
# **7. Defining the process of simulated annealing**
# The class below defines the simulated annealing process.  This class is an adaptation of the class anneal.py found in the python code provided in this github https://github.com/chncyhn/simulated-annealing-tsp. You are not asked to changed this class, just go through it and try to understand it so as to get a better understanding of the *simulated annealing* algorithm.

# %%
# class to perform a simulated annealing
# must start with a set of nodes, all other parameters have defaults
class SimAnneal(object):
    def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
        # set of nodes
        self.nodes = nodes
        # number of nodes
        self.N = len(nodes)
        # set the temperature T to sqrt(N) if not specified
        self.T = math.sqrt(self.N) if T == -1 else T
        # set alpha (rate at which the temperature is decreased)
        self.alpha = 0.995 if alpha == -1 else alpha
        # set stopping temprature
        self.stopping_temperature = 0.00000001 if stopping_T == -1 else stopping_T
        # set stopping iteration
        self.stopping_iter = 100000 if stopping_iter == -1 else stopping_iter
        # start at iteration 1
        self.iteration = 1

        # calculate the distances
        self.allDist = distDict(nodes)
        
        # start with greedy solution if randomizedGreedy is false,
        #  start with the randomized greedy solution if randomizedGreedy is true
        if (randomizedGreedy):
            self.cur_solution = randomized_greedy_solution(nodes, k)
            self.improvementMessage = 'Improvement over randomized greedy heuristic: '
        else:
            self.cur_solution = greedy_solution(nodes)
            self.improvementMessage = 'Improvement over greedy heuristic: '
        
        # so far, the best solution is the one we have
        self.best_solution = list(self.cur_solution)

        # calculate fitness of the current solution
        self.cur_fitness = self.fitness(self.cur_solution)
        # initial fitness for initial solution
        self.initial_fitness = self.cur_fitness
        # best fitness so far
        self.best_fitness = self.cur_fitness
        # build the fitness list as we explore solutions
        self.fitness_list = [self.cur_fitness]


    def fitness(self, sol):
        """ Objective value of a solution """
        return totalDist(sol, self.allDist)

    # acceptance propability
    def p_accept(self, candidate_fitness):
        """
        Probability of accepting if the candidate is worse than current
        Depends on the current temperature and difference between candidate and current
        """
        return math.exp(-abs(candidate_fitness - self.cur_fitness) / self.T)

    def accept(self, candidate):
        """
        Accept with probability 1 if candidate is better than current
        Accept with probabilty p_accept(..) if candidate is worse
        """
        candidate_fitness = self.fitness(candidate)
        # test if fitness is smaller then the current one
        if candidate_fitness < self.cur_fitness:
            self.cur_fitness = candidate_fitness
            self.cur_solution = candidate
            # test if fitness is better than best so far, keep it as best if so
            if candidate_fitness < self.best_fitness:
                self.best_fitness = candidate_fitness
                self.best_solution = candidate

        # if solution is worst than the current one, there is still a possibility to pursue it
        else:
            if random.random() < self.p_accept(candidate_fitness):
                self.cur_fitness = candidate_fitness
                self.cur_solution = candidate

    def anneal(self):
        """
        Execute simulated annealing algorithm
        """
        # go through the temperature schedule
        print(self.T)
        print(self.stopping_temperature)
        while (self.T >= self.stopping_temperature) and (self.iteration < self.stopping_iter):
            # explore current solution
            candidate = list(self.cur_solution)
            # modify the solution to switch two cities
            # first chosen city between [2,N-1] - not changing the first city
            l = random.randint(2, self.N - 1)
            # second city between [0,N-1] Not sure why ??
            i = random.randint(0, self.N - l)
            # the chosen nodes are switch
            candidate[i:(i + l)] = reversed(candidate[i:(i + l)])
            # perform acceptance test 
            self.accept(candidate)
            # multiply the temperature by alpha (this will reduce it)
            self.T *= self.alpha
            self.iteration += 1
            
            # add current fitness to list (to be able to display)
            self.fitness_list.append(self.cur_fitness)

        print('Best fitness obtained: ', self.best_fitness)
        print(self.improvementMessage,
              round((self.initial_fitness - self.best_fitness) / (self.initial_fitness), 4))

        return self.best_solution
    
    def plot_learning(self):
        """
        Plot the fitness through iterations
        """
        plt.plot([i for i in range(len(self.fitness_list))], self.fitness_list)
        plt.ylabel('Fitness')
        plt.xlabel('Iteration')
        plt.show()

# %% [markdown]
# #### 8. Refining a greedy solution through simulated annealing.

# %% [markdown]
# **(TO DO) Q5 - 5 marks**
# Put comments in the code below explaining what it does.  Also run it a few times.  It will show you how there can be improvement (or not) from the greedy solution and randomized greedy solution to the annealed one.

# %%
'''Find greedy solution on the extended cities (moreCities)
   Calculate the distances for them
   Print the greedy solution with the respective total distance
   Show the greedy path visually
'''
firstSol = greedy_solution(moreCities)
distances = distDict(moreCities)
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))
showPath(firstSol, moreCities)

'''Find the Simulated Annealing for extended cities, starting with a greedy solution
   Get a better solution in regards to best fitness and how much it improved over the greedy heuristic
   Show the better path visually 
'''
sa = SimAnneal(moreCities, False)
betterSol = sa.anneal()
showPath(betterSol, moreCities)
'''Find the randomized greedy solution on the extended cities, given a k value of 4 for kClosestNodes
   This will calculate the probability distribution for 4 closestNodes and randomly pick 1 based on probability distribution
   Print the solution with respective total distance
   Show the randomized greedy path visually 
'''
secondSol = randomized_greedy_solution(moreCities, 4)
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))
showPath(secondSol, moreCities)
'''Find the Simulated Annealing for extended cities, starting with a randomized greedy solution to perform, given k value 4
   Get a better solution in regards to best fitness and how much it improved over the randomized greedy heuristic
   Show the better solution visually
'''
sa2 = SimAnneal(moreCities, True, 4)
betterSol2 = sa2.anneal()
showPath(betterSol2, moreCities)
# Out:
# Solution ['F', 'A', 'C', 'B', 'D', 'G', 'E'] takes a total of 7.0
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.0
# Improvement over greedy heuristic:  0.1429
# Closest Nodes: ['A', 'D', 'E', 'C']
# Normalized distances: [0.2857019559920368, 0.2857019559920368, 0.2857019559920368, 0.14289413202388965]
# Node selected by probability distribution: D
# Closest Nodes: ['C', 'A', 'B', 'E']
# Normalized distances: [0.4999622414476879, 0.2500566378284682, 0.12499056036192198, 0.12499056036192198]
# Node selected by probability distribution: B
# Closest Nodes: ['C', 'A', 'F', 'E']
# Normalized distances: [0.5478848727697965, 0.2740251919928801, 0.1095836372391034, 0.06850629799822003]
# Node selected by probability distribution: F
# Closest Nodes: ['A', 'E', 'C']
# Normalized distances: [0.4444444444444444, 0.4444444444444444, 0.1111111111111111]
# Node selected by probability distribution: C
# Closest Nodes: ['A', 'E']
# Normalized distances: [0.8333248884610154, 0.1666751115389846]
# Node selected by probability distribution: E
# Closest Nodes: ['A']
# Normalized distances: [1.0]
# Node selected by probability distribution: A
# Solution ['G', 'D', 'B', 'F', 'C', 'E', 'A'] takes a total of 10.886
# Closest Nodes: ['A', 'B', 'D', 'G']
# Normalized distances: [0.2857019559920368, 0.2857019559920368, 0.2857019559920368, 0.14289413202388965]
# Node selected by probability distribution: D
# Closest Nodes: ['G', 'A', 'B', 'E']
# Normalized distances: [0.4999622414476879, 0.2500566378284682, 0.12499056036192198, 0.12499056036192198]
# Node selected by probability distribution: B
# Closest Nodes: ['A', 'F', 'G', 'E']
# Normalized distances: [0.4878508006899021, 0.19509324956881122, 0.19509324956881122, 0.12196270017247553]
# Node selected by probability distribution: A
# Closest Nodes: ['F', 'G', 'E']
# Normalized distances: [0.39997583416153343, 0.39997583416153343, 0.2000483316769332]
# Node selected by probability distribution: G
# Closest Nodes: ['E', 'F']
# Normalized distances: [0.6665995420411309, 0.3334004579588691]
# Node selected by probability distribution: F
# Closest Nodes: ['E']
# Normalized distances: [1.0]
# Node selected by probability distribution: E
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.0
# Improvement over randomized greedy heuristic:  0.2335

# %% [markdown]
# **9. Moving toward a larger example**
# There are a set of coordinates defined in the file *coord.txt* (available in the Jupyter Notebooks module in Brightspace). This data file is also from the github https://github.com/chncyhn/simulated-annealing-tsp.  It contains a larger example with 45 cities, to test.  Here is the beginning of the file:
#
# 1 0 0
# 2 3 5
# 3 2.5 9
# 4 48 16
# 5 48 17
# 6 69 16
# ...
#
# Make sure to put the file *coord.txt* in the same repertory as your notebook or modify the path below when opening the file to read.  We will assume the first number is the label, and the other two numbers are the coordinates.

# %%
# reading the coordinates
manyCities = {}
with open('coord.txt','r') as f:
    i = 0
    for line in f.readlines():
        line = [float(x.replace('\n','')) for x in line.split(' ')]
        label = str(int(line[0]))
        manyCities[label] = (line[1], line[2])
        i += 1

# %% [markdown]
# Show the nodes from that larger set of cities.

# %%
showNodes(manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# %% [markdown]
# Testing the annealing process with the larger example. The steps are the same as the ones you had to comment in Question 4. Look at the additional step *plot_learning*, it shows the value of the fitness function as the annealing process occurs.  Run it multiple times, it is a probabilistic approach, so the result might be slightly different each time.

# %%
firstSol = greedy_solution(manyCities)
distances = distDict(manyCities)
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa = SimAnneal(manyCities, False)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

secondSol = randomized_greedy_solution(manyCities, 3)
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa2 = SimAnneal(manyCities, True, 4)
betterSol2 = sa2.anneal()
sa2.plot_learning()
showPath(betterSol2, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# Solution ['20', '26', '21', '22', '1', '25', '10', '16', '2', '3', '17', '11', '18', '19', '12', '13', '15', '14', '38', '39', '43', '37', '40', '41', '35', '32', '33', '42', '31', '44', '45', '9', '27', '23', '24', '4', '5', '36', '8', '6', '7', '28', '30', '34', '29'] takes a total of 627.118
# 6.708203932499369
# 1e-08
# Best fitness obtained:  509.543
# Improvement over greedy heuristic:  0.136
# Closest Nodes: ['38', '43', '37']
# Normalized distances: [0.929215513669469, 0.03572928124568545, 0.035055205084845595]
# Node selected by probability distribution: 43
# Closest Nodes: ['37', '38', '40']
# Normalized distances: [0.5545084421946439, 0.2772968390432785, 0.16819471876207748]
# Node selected by probability distribution: 38
# Closest Nodes: ['37', '2', '10']
# Normalized distances: [0.7215723018299857, 0.14298174089450205, 0.13544595727551217]
# Node selected by probability distribution: 2
# Closest Nodes: ['16', '3', '10']
# Normalized distances: [0.448303482183377, 0.2758482589083115, 0.2758482589083115]
# Node selected by probability distribution: 3
# Closest Nodes: ['17', '16', '10']
# Normalized distances: [0.5788529856315817, 0.23799431188342568, 0.18315270248499266]
# Node selected by probability distribution: 17
# Closest Nodes: ['16', '10', '25']
# Normalized distances: [0.39406231901959843, 0.3039903215238786, 0.3019473594565229]
# Node selected by probability distribution: 10
# Closest Nodes: ['16', '25', '1']
# Normalized distances: [0.7433767939183448, 0.1285023299559744, 0.1281208761256809]
# Node selected by probability distribution: 16
# Closest Nodes: ['25', '1', '22']
# Normalized distances: [0.48928402261888787, 0.4868648222570764, 0.023851155124035704]
# Node selected by probability distribution: 22
# Closest Nodes: ['21', '1', '25']
# Normalized distances: [0.9950900659400717, 0.0024571619039377643, 0.002452772155990728]
# Node selected by probability distribution: 1
# Closest Nodes: ['25', '21', '11']
# Normalized distances: [0.9999987247399923, 9.433272461669098e-07, 3.319327616423722e-07]
# Node selected by probability distribution: 11
# Closest Nodes: ['18', '19', '25']
# Normalized distances: [0.48973168657778915, 0.3780796066470392, 0.13218870677517155]
# Node selected by probability distribution: 18
# Closest Nodes: ['19', '25', '12']
# Normalized distances: [0.7454487250299621, 0.1507013428764074, 0.10384993209363066]
# Node selected by probability distribution: 12
# Closest Nodes: ['13', '15', '14']
# Normalized distances: [0.36403220745958403, 0.3206507154993459, 0.3153170770410702]
# Node selected by probability distribution: 14
# Closest Nodes: ['13', '15', '19']
# Normalized distances: [0.4997575525284143, 0.4997575525284143, 0.0004848949431713029]
# Node selected by probability distribution: 15
# Closest Nodes: ['13', '19', '25']
# Normalized distances: [0.9988289322860047, 0.0008100848387025265, 0.00036098287529280154]
# Node selected by probability distribution: 25
# Closest Nodes: ['21', '9', '20']
# Normalized distances: [0.7275493112432705, 0.15653829487913187, 0.11591239387759766]
# Node selected by probability distribution: 20
# Closest Nodes: ['26', '21', '9']
# Normalized distances: [0.3732672838164972, 0.3579895923319485, 0.2687431238515543]
# Node selected by probability distribution: 26
# Closest Nodes: ['21', '27', '23']
# Normalized distances: [0.3519988050442273, 0.3404226477948599, 0.30757854716091276]
# Node selected by probability distribution: 27
# Closest Nodes: ['23', '24', '21']
# Normalized distances: [0.7139697110572873, 0.28551899643680245, 0.000511292505910258]
# Node selected by probability distribution: 21
# Closest Nodes: ['9', '44', '45']
# Normalized distances: [0.6665327515904035, 0.16843806495404565, 0.1650291834555508]
# Node selected by probability distribution: 45
# Closest Nodes: ['44', '31', '42']
# Normalized distances: [0.9936371227484436, 0.0032579196055104592, 0.0031049576460459452]
# Node selected by probability distribution: 44
# Closest Nodes: ['31', '42', '40']
# Normalized distances: [0.3836850519810999, 0.36734142391757924, 0.2489735241013209]
# Node selected by probability distribution: 42
# Closest Nodes: ['31', '41', '40']
# Normalized distances: [0.969980757973853, 0.015095506933579401, 0.014923735092567657]
# Node selected by probability distribution: 40
# Closest Nodes: ['41', '35', '31']
# Normalized distances: [0.9907874982654508, 0.006191551177274763, 0.003020950557274387]
# Node selected by probability distribution: 41
# Closest Nodes: ['35', '31', '32']
# Normalized distances: [0.5907594727081436, 0.24899132805535143, 0.16024919923650494]
# Node selected by probability distribution: 35
# Closest Nodes: ['32', '33', '31']
# Normalized distances: [0.46831498946162226, 0.33603017970812354, 0.19565483083025415]
# Node selected by probability distribution: 32
# Closest Nodes: ['33', '31', '36']
# Normalized distances: [0.976754725231273, 0.015624305882665715, 0.007620968886061195]
# Node selected by probability distribution: 33
# Closest Nodes: ['31', '34', '36']
# Normalized distances: [0.4770929258116171, 0.29051147739553496, 0.23239559679284796]
# Node selected by probability distribution: 34
# Closest Nodes: ['30', '31', '36']
# Normalized distances: [0.39539612106117294, 0.3439992609380039, 0.2606046180008231]
# Node selected by probability distribution: 31
# Closest Nodes: ['37', '36', '4']
# Normalized distances: [0.4863057744954748, 0.29749894365615587, 0.21619528184836942]
# Node selected by probability distribution: 36
# Closest Nodes: ['4', '5', '8']
# Normalized distances: [0.38175445748525666, 0.32537049503057336, 0.29287504748416987]
# Node selected by probability distribution: 5
# Closest Nodes: ['4', '8', '6']
# Normalized distances: [0.9940960056626245, 0.003654951989240979, 0.002249042348134495]
# Node selected by probability distribution: 6
# Closest Nodes: ['7', '8', '28']
# Normalized distances: [0.966563702654124, 0.028427875135769786, 0.005008422210106259]
# Node selected by probability distribution: 8
# Closest Nodes: ['7', '4', '28']
# Normalized distances: [0.7591092288965973, 0.1288946622783934, 0.1119961088250093]
# Node selected by probability distribution: 28
# Closest Nodes: ['7', '30', '4']
# Normalized distances: [0.5258803568767162, 0.39556475377661715, 0.07855488934666649]
# Node selected by probability distribution: 4
# Closest Nodes: ['7', '37', '30']
# Normalized distances: [0.4437435224694356, 0.4252985830236593, 0.130957894506905]
# Node selected by probability distribution: 7
# Closest Nodes: ['30', '37', '9']
# Normalized distances: [0.6896737080532322, 0.23732490476856244, 0.07300138717820535]
# Node selected by probability distribution: 30
# Closest Nodes: ['37', '9', '29']
# Normalized distances: [0.5605629650375124, 0.2509877810768349, 0.18844925388565276]
# Node selected by probability distribution: 29
# Closest Nodes: ['9', '37', '23']
# Normalized distances: [0.40451854170154383, 0.37057667464623484, 0.22490478365222127]
# Node selected by probability distribution: 37
# Closest Nodes: ['9', '19', '13']
# Normalized distances: [0.5331662288625334, 0.274502875317874, 0.19233089581959265]
# Node selected by probability distribution: 19
# Closest Nodes: ['13', '9', '23']
# Normalized distances: [0.541612899245601, 0.29653368573420424, 0.16185341502019482]
# Node selected by probability distribution: 9
# Closest Nodes: ['23', '24', '13']
# Normalized distances: [0.39372604346210577, 0.3806179849662136, 0.2256559715716806]
# Node selected by probability distribution: 24
# Closest Nodes: ['23', '13']
# Normalized distances: [0.999896704904734, 0.00010329509526608578]
# Node selected by probability distribution: 23
# Closest Nodes: ['13']
# Normalized distances: [1.0]
# Node selected by probability distribution: 13
# Solution ['39', '43', '38', '2', '3', '17', '10', '16', '22', '1', '11', '18', '12', '14', '15', '25', '20', '26', '27', '21', '45', '44', '42', '40', '41', '35', '32', '33', '34', '31', '36', '5', '6', '8', '28', '4', '7', '30', '29', '37', '19', '9', '24', '23', '13'] takes a total of 1053.953
# Closest Nodes: ['25', '10', '16', '2']
# Normalized distances: [0.9999707671244443, 1.3788422972300652e-05, 1.2503410619062514e-05, 2.941041964350071e-06]
# Node selected by probability distribution: 25
# Closest Nodes: ['10', '16', '2', '17']
# Normalized distances: [0.4530684262871687, 0.41166053107687967, 0.09664980899608289, 0.03862123363986865]
# Node selected by probability distribution: 16
# Closest Nodes: ['10', '2', '3', '17']
# Normalized distances: [0.8549762359027321, 0.10688430055162554, 0.02169756124978969, 0.016441902295852743]
# Node selected by probability distribution: 3
# Closest Nodes: ['2', '17', '10', '11']
# Normalized distances: [0.47120263408857305, 0.37810139379765395, 0.11963364413128895, 0.03106232798248405]
# Node selected by probability distribution: 2
# Closest Nodes: ['10', '17', '22', '21']
# Normalized distances: [0.6564941011032924, 0.2601892928468872, 0.042290813674621966, 0.04102579237519843]
# Node selected by probability distribution: 21
# Closest Nodes: ['22', '10', '9', '20']
# Normalized distances: [0.9963159578519115, 0.0015941055325630585, 0.0010690558155111627, 0.0010208808000141728]
# Node selected by probability distribution: 10
# Closest Nodes: ['17', '22', '38', '11']
# Normalized distances: [0.48801363001184794, 0.27593373682192135, 0.11874717779987408, 0.11730545536635655]
# Node selected by probability distribution: 11
# Closest Nodes: ['18', '19', '17', '22']
# Normalized distances: [0.3882790878050254, 0.29975680318426234, 0.24790421427852585, 0.06405989473218637]
# Node selected by probability distribution: 19
# Closest Nodes: ['18', '17', '12', '22']
# Normalized distances: [0.672837914620772, 0.1602830885516762, 0.10053004655545049, 0.06634895027210126]
# Node selected by probability distribution: 18
# Closest Nodes: ['17', '12', '22', '13']
# Normalized distances: [0.6068161567358858, 0.1548300071544842, 0.1288410887779717, 0.10951274733165811]
# Node selected by probability distribution: 17
# Closest Nodes: ['22', '38', '39', '9']
# Normalized distances: [0.40851907823833083, 0.23878510514712162, 0.21586666357756817, 0.1368291530369794]
# Node selected by probability distribution: 38
# Closest Nodes: ['39', '37', '43', '40']
# Normalized distances: [0.9404360745280342, 0.028929605493961327, 0.025411436865780457, 0.005222883112224229]
# Node selected by probability distribution: 40
# Closest Nodes: ['41', '35', '42', '31']
# Normalized distances: [0.9870259769962175, 0.006168044974901764, 0.003796496499823195, 0.003009481529057556]
# Node selected by probability distribution: 35
# Closest Nodes: ['41', '32', '33', '42']
# Normalized distances: [0.4467713837010185, 0.25083718329814936, 0.17998327125521998, 0.1224081617456121]
# Node selected by probability distribution: 33
# Closest Nodes: ['32', '42', '31', '41']
# Normalized distances: [0.9590602867298343, 0.01474968187560964, 0.013995934157730113, 0.012194097236826105]
# Node selected by probability distribution: 41
# Closest Nodes: ['42', '31', '32', '43']
# Normalized distances: [0.35944703920701637, 0.28425965212962473, 0.1829476632169832, 0.1733456454463757]
# Node selected by probability distribution: 31
# Closest Nodes: ['42', '32', '43', '44']
# Normalized distances: [0.9847135339134293, 0.007878187265093152, 0.004035969241940999, 0.003372309579536581]
# Node selected by probability distribution: 42
# Closest Nodes: ['32', '43', '44', '45']
# Normalized distances: [0.4428112052905889, 0.22827980379622556, 0.16840793992413067, 0.16050105098905487]
# Node selected by probability distribution: 44
# Closest Nodes: ['45', '43', '39', '9']
# Normalized distances: [0.9917290406805045, 0.0036462494662245055, 0.0024547140929197407, 0.002169995760351348]
# Node selected by probability distribution: 45
# Closest Nodes: ['43', '39', '9', '37']
# Normalized distances: [0.34320835150401047, 0.23522649273946544, 0.2326168169755089, 0.18894833878101533]
# Node selected by probability distribution: 37
# Closest Nodes: ['43', '39', '4', '5']
# Normalized distances: [0.5431009514166346, 0.379186998495504, 0.03979538807002094, 0.03791666201784055]
# Node selected by probability distribution: 43
# Closest Nodes: ['39', '32', '4', '5']
# Normalized distances: [0.8049512430507691, 0.0822325722813585, 0.05781359942695784, 0.05500258524091447]
# Node selected by probability distribution: 39
# Closest Nodes: ['22', '32', '4', '5']
# Normalized distances: [0.26250722146878325, 0.24982926897990193, 0.24781980195197817, 0.23984370759933663]
# Node selected by probability distribution: 4
# Closest Nodes: ['5', '36', '8', '6']
# Normalized distances: [0.9833997443256275, 0.010659463642896248, 0.0037108606384476917, 0.0022299313930286336]
# Node selected by probability distribution: 8
# Closest Nodes: ['6', '7', '36', '5']
# Normalized distances: [0.4622430711082965, 0.34927731908422194, 0.1306953119471141, 0.05778429786036747]
# Node selected by probability distribution: 5
# Closest Nodes: ['36', '6', '7', '32']
# Normalized distances: [0.6043410938135856, 0.1479967292655883, 0.13487450250040905, 0.11278767442041701]
# Node selected by probability distribution: 6
# Closest Nodes: ['7', '28', '36', '30']
# Normalized distances: [0.9898359649935612, 0.00512901158798192, 0.0035192110422926745, 0.001515812376164116]
# Node selected by probability distribution: 30
# Closest Nodes: ['28', '34', '7', '36']
# Normalized distances: [0.4863735189798713, 0.2280520164011415, 0.17502460370453815, 0.11054986091444916]
# Node selected by probability distribution: 34
# Closest Nodes: ['32', '36', '28', '7']
# Normalized distances: [0.5338431661663433, 0.19637071793630603, 0.14359793966650355, 0.12618817623084713]
# Node selected by probability distribution: 7
# Closest Nodes: ['28', '36', '32', '9']
# Normalized distances: [0.5694749396595016, 0.31000901049266233, 0.10419974240310355, 0.016316307444732617]
# Node selected by probability distribution: 32
# Closest Nodes: ['36', '28', '9', '22']
# Normalized distances: [0.7132691325280307, 0.15018453983997612, 0.07509304415332532, 0.061453283478667776]
# Node selected by probability distribution: 22
# Closest Nodes: ['9', '20', '26', '27']
# Normalized distances: [0.4398899219026533, 0.38970915391802236, 0.13549149580633912, 0.034909428372985184]
# Node selected by probability distribution: 26
# Closest Nodes: ['20', '27', '23', '24']
# Normalized distances: [0.5306533246026176, 0.17009238870061594, 0.1536818132946049, 0.14557247340216156]
# Node selected by probability distribution: 24
# Closest Nodes: ['23', '27', '20', '9']
# Normalized distances: [0.8327008563911303, 0.16655029753631623, 0.0004989317059844331, 0.0002499143665690531]
# Node selected by probability distribution: 23
# Closest Nodes: ['27', '20', '9', '12']
# Normalized distances: [0.9978659096988856, 0.0012516449610322504, 0.0006194097728086013, 0.0002630355672736629]
# Node selected by probability distribution: 12
# Closest Nodes: ['13', '15', '14', '20']
# Normalized distances: [0.3589618518436348, 0.31618459101152635, 0.31092524115507275, 0.013928315989766236]
# Node selected by probability distribution: 14
# Closest Nodes: ['13', '15', '20', '9']
# Normalized distances: [0.4998891224441762, 0.4998891224441762, 0.0001132283134135091, 0.0001085267982340318]
# Node selected by probability distribution: 9
# Closest Nodes: ['20', '27', '36', '15']
# Normalized distances: [0.7965221371590043, 0.08391397278729963, 0.0733110069995216, 0.04625288305417444]
# Node selected by probability distribution: 15
# Closest Nodes: ['13', '20', '36', '27']
# Normalized distances: [0.9995337649441948, 0.00018585526855910214, 0.00017424880335075796, 0.00010613098389528656]
# Node selected by probability distribution: 20
# Closest Nodes: ['27', '13', '36', '28']
# Normalized distances: [0.5915329703406915, 0.16450178052245784, 0.15672187823163025, 0.08724337090522036]
# Node selected by probability distribution: 13
# Closest Nodes: ['36', '27', '28', '29']
# Normalized distances: [0.41605633692479227, 0.2612928064995335, 0.24511075970313542, 0.0775400968725388]
# Node selected by probability distribution: 27
# Closest Nodes: ['36', '28', '29']
# Normalized distances: [0.44525210112701896, 0.2970786418307611, 0.25766925704221993]
# Node selected by probability distribution: 28
# Closest Nodes: ['36', '29']
# Normalized distances: [0.9411990154919903, 0.058800984508009746]
# Node selected by probability distribution: 36
# Closest Nodes: ['29']
# Normalized distances: [1.0]
# Node selected by probability distribution: 29
# 6.708203932499369
# 1e-08
# Best fitness obtained:  529.757
# Improvement over randomized greedy heuristic:  0.5959

# %% [markdown]
# **(TO DO) Q6 - 2 marks**
# Try the annealing again, but provide a different temperature schedule, by changing alpha, and the starting and stopping temperatures.  These are all parameters to the class which can be set.  Try also changing the number of iterations to do.  Explore 4 variations below.

# %%
# (TO DO) Look at this line from the SimAnneal class above
# def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
# This means that parameters k, T, alpha, stopping_T and stopping_iter all have defaults, but could be changed
# For example, calling SimAnneal(manyCities, False, stopping_iter=100) means that I set a maximum of 100 iterations for a 
# Greedy solution. Calling  SimAnneal(manyCities, True, k=3, stopping_iter=100) is the same for a randomized greedy solution
# with k = 3.
# Try four variations and look at the differences
# The key point of this question is to use different parameters to understand how they work
# What you need to do is create and run these four different examples

# Test 1 (Use a Greedy solution, see comment above) ...
sa = SimAnneal(manyCities, False, alpha = 2, stopping_T = -100, stopping_iter = 100)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 2 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, 4, T = 25, alpha = 2, stopping_T = -50, stopping_iter = 500) 
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 3 (Use a Greedy solution, see comment above)...
sa = SimAnneal(manyCities, False,alpha = 1, stopping_T = -50, stopping_iter = 50)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 4 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True,3, T = 25, alpha = 1, stopping_T= - 100, stopping_iter = 1000)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# 6.708203932499369
# -100
# Best fitness obtained:  623.361
# Improvement over greedy heuristic:  0.0
# Closest Nodes: ['23', '24', '26', '20']
# Normalized distances: [0.7122596304795653, 0.28483512920431975, 0.0019507364832573777, 0.0009545038328575386]
# Node selected by probability distribution: 20
# Closest Nodes: ['26', '21', '22', '9']
# Normalized distances: [0.2778227242420629, 0.2664515431812182, 0.25570030836497326, 0.20002542421174568]
# Node selected by probability distribution: 26
# Closest Nodes: ['21', '22', '23', '24']
# Normalized distances: [0.2727045781904015, 0.26328772437214915, 0.2382908031559774, 0.22571689428147187]
# Node selected by probability distribution: 23
# Closest Nodes: ['24', '21', '22', '9']
# Normalized distances: [0.999015152523708, 0.00034003641345492453, 0.00033465582222884843, 0.0003101552406084303]
# Node selected by probability distribution: 9
# Closest Nodes: ['22', '21', '45', '44']
# Normalized distances: [0.337823266075379, 0.3265866919346827, 0.16909509673619402, 0.16649494525374442]
# Node selected by probability distribution: 44
# Closest Nodes: ['45', '43', '31', '42']
# Normalized distances: [0.9897265379862821, 0.003638886946745484, 0.0033894774167551396, 0.0032450976502171464]
# Node selected by probability distribution: 45
# Closest Nodes: ['31', '43', '42', '39']
# Normalized distances: [0.27484424361926507, 0.27484424361926507, 0.2619400841733299, 0.18837142858813993]
# Node selected by probability distribution: 39
# Closest Nodes: ['38', '43', '37', '40']
# Normalized distances: [0.9237498585971928, 0.035519121251156215, 0.034849010013128554, 0.0058820101385223394]
# Node selected by probability distribution: 40
# Closest Nodes: ['41', '35', '42', '31']
# Normalized distances: [0.9870259769962175, 0.006168044974901764, 0.003796496499823195, 0.003009481529057556]
# Node selected by probability distribution: 35
# Closest Nodes: ['41', '32', '33', '42']
# Normalized distances: [0.4467713837010185, 0.25083718329814936, 0.17998327125521998, 0.1224081617456121]
# Node selected by probability distribution: 41
# Closest Nodes: ['42', '31', '32', '43']
# Normalized distances: [0.35944703920701637, 0.28425965212962473, 0.1829476632169832, 0.1733456454463757]
# Node selected by probability distribution: 31
# Closest Nodes: ['42', '32', '33', '43']
# Normalized distances: [0.9809711174248671, 0.007848246112762594, 0.00716000597359783, 0.004020630488772509]
# Node selected by probability distribution: 33
# Closest Nodes: ['32', '42', '34', '36']
# Normalized distances: [0.9695803297984056, 0.014911472839875525, 0.0086158890359005, 0.006892308325818409]
# Node selected by probability distribution: 42
# Closest Nodes: ['32', '43', '37', '38']
# Normalized distances: [0.4856704403035632, 0.2503747680670541, 0.162817279019223, 0.10113751261015955]
# Node selected by probability distribution: 43
# Closest Nodes: ['37', '38', '32', '10']
# Normalized distances: [0.6139103089003954, 0.30700233785513087, 0.04462968977911645, 0.03445766346535717]
# Node selected by probability distribution: 38
# Closest Nodes: ['37', '2', '10', '16']
# Normalized distances: [0.6388083800493115, 0.1265818186837332, 0.11991038504660434, 0.11469941622035093]
# Node selected by probability distribution: 2
# Closest Nodes: ['16', '3', '10', '25']
# Normalized distances: [0.3959450792242144, 0.24363130126800273, 0.24363130126800273, 0.1167923182397802]
# Node selected by probability distribution: 3
# Closest Nodes: ['17', '16', '10', '25']
# Normalized distances: [0.5101696267879147, 0.209755278602798, 0.16142085847586363, 0.11865423613342371]
# Node selected by probability distribution: 16
# Closest Nodes: ['10', '25', '1', '17']
# Normalized distances: [0.7504224065796811, 0.11786455688299437, 0.11728179111612977, 0.014431245421194954]
# Node selected by probability distribution: 17
# Closest Nodes: ['10', '25', '1', '11']
# Normalized distances: [0.2742383641768574, 0.2723953496604134, 0.271804790810436, 0.18156149535229324]
# Node selected by probability distribution: 25
# Closest Nodes: ['1', '10', '22', '21']
# Normalized distances: [0.9999842425547855, 1.3829661558712962e-05, 9.85934274904346e-07, 9.418493806854554e-07]
# Node selected by probability distribution: 10
# Closest Nodes: ['1', '22', '21', '11']
# Normalized distances: [0.8962388196154212, 0.04361928763533934, 0.04159838133322956, 0.018543511416009892]
# Node selected by probability distribution: 22
# Closest Nodes: ['21', '1', '11', '18']
# Normalized distances: [0.9967467594057282, 0.002461252753811206, 0.000505978372264111, 0.00028600946819660393]
# Node selected by probability distribution: 21
# Closest Nodes: ['1', '11', '18', '19']
# Normalized distances: [0.6913837844595148, 0.15134707779871348, 0.08463203087194134, 0.07263710686983042]
# Node selected by probability distribution: 11
# Closest Nodes: ['18', '19', '1', '12']
# Normalized distances: [0.47368960392803594, 0.36569489790907483, 0.12775550820473652, 0.03285998995815262]
# Node selected by probability distribution: 18
# Closest Nodes: ['19', '1', '12', '13']
# Normalized distances: [0.6945178129367906, 0.14029205255732705, 0.09675464628154488, 0.0684354882243374]
# Node selected by probability distribution: 13
# Closest Nodes: ['15', '14', '12', '19']
# Normalized distances: [0.5534776130165047, 0.4428090132012063, 0.003255952840321689, 0.0004574209419674055]
# Node selected by probability distribution: 12
# Closest Nodes: ['15', '14', '19', '1']
# Normalized distances: [0.42581560041270244, 0.418732670755246, 0.12156384322249242, 0.033887885609559125]
# Node selected by probability distribution: 1
# Closest Nodes: ['19', '37', '32', '4']
# Normalized distances: [0.4026178189508525, 0.357500495538402, 0.12019713645627135, 0.11968454905447405]
# Node selected by probability distribution: 37
# Closest Nodes: ['4', '5', '32', '36']
# Normalized distances: [0.27518419967776175, 0.26219285193230557, 0.24725993302030053, 0.21536301536963212]
# Node selected by probability distribution: 4
# Closest Nodes: ['5', '36', '8', '6']
# Normalized distances: [0.9833997443256275, 0.010659463642896248, 0.0037108606384476917, 0.0022299313930286336]
# Node selected by probability distribution: 6
# Closest Nodes: ['7', '8', '28', '36']
# Normalized distances: [0.9632535108065308, 0.028330518158407172, 0.004991269860681514, 0.0034247011743805253]
# Node selected by probability distribution: 8
# Closest Nodes: ['7', '36', '5', '28']
# Normalized distances: [0.5927107419202253, 0.22178512911395232, 0.09805782449875904, 0.08744630446706339]
# Node selected by probability distribution: 36
# Closest Nodes: ['5', '32', '7', '28']
# Normalized distances: [0.5215207736603057, 0.2202917069381023, 0.1807798599385563, 0.07740765946303578]
# Node selected by probability distribution: 5
# Closest Nodes: ['7', '32', '28', '34']
# Normalized distances: [0.38342221650341834, 0.320633621024189, 0.16128618938554268, 0.13465797308684999]
# Node selected by probability distribution: 28
# Closest Nodes: ['7', '30', '34', '32']
# Normalized distances: [0.48499952765371623, 0.36481438454468373, 0.0824436351999961, 0.06774245260160379]
# Node selected by probability distribution: 34
# Closest Nodes: ['32', '30', '7', '29']
# Normalized distances: [0.545845135694589, 0.30463709261586597, 0.12902516421146243, 0.020492607478082334]
# Node selected by probability distribution: 29
# Closest Nodes: ['30', '32', '7', '24']
# Normalized distances: [0.3419056618907371, 0.30753816034403825, 0.220441348706039, 0.13011482905918567]
# Node selected by probability distribution: 30
# Closest Nodes: ['7', '32', '19', '15']
# Normalized distances: [0.5799139798945093, 0.3552970233946146, 0.033020979721942414, 0.0317680169889337]
# Node selected by probability distribution: 32
# Closest Nodes: ['7', '19', '15', '14']
# Normalized distances: [0.6970435072320583, 0.11613486314554841, 0.0946043854936999, 0.09221724412869325]
# Node selected by probability distribution: 19
# Closest Nodes: ['15', '14', '24', '7']
# Normalized distances: [0.41513051936651957, 0.3973287164053865, 0.12441918758475719, 0.06312157664333695]
# Node selected by probability distribution: 14
# Closest Nodes: ['15', '7', '24']
# Normalized distances: [0.9997078821330723, 0.00016591566996045483, 0.0001262021969673757]
# Node selected by probability distribution: 15
# Closest Nodes: ['7', '24']
# Normalized distances: [0.5696525384626944, 0.43034746153730574]
# Node selected by probability distribution: 24
# Closest Nodes: ['7']
# Normalized distances: [1.0]
# Node selected by probability distribution: 7
# 25
# -50
# Best fitness obtained:  1174.613
# Improvement over randomized greedy heuristic:  0.0
# 6.708203932499369
# -50
# Best fitness obtained:  595.258
# Improvement over greedy heuristic:  0.0
# Closest Nodes: ['42', '41', '40']
# Normalized distances: [0.9760825428304646, 0.012012998920428746, 0.011904458249106735]
# Node selected by probability distribution: 40
# Closest Nodes: ['41', '35', '42']
# Normalized distances: [0.9900053799006964, 0.006186663624807113, 0.003807956474496648]
# Node selected by probability distribution: 42
# Closest Nodes: ['41', '32', '35']
# Normalized distances: [0.48354766493445733, 0.26786952086059335, 0.24858281420494938]
# Node selected by probability distribution: 32
# Closest Nodes: ['33', '35', '41']
# Normalized distances: [0.9536377849157994, 0.03125936859257411, 0.015102846491626343]
# Node selected by probability distribution: 41
# Closest Nodes: ['35', '43', '33']
# Normalized distances: [0.6780578868384597, 0.17427617336116466, 0.1476659398003757]
# Node selected by probability distribution: 43
# Closest Nodes: ['37', '39', '38']
# Normalized distances: [0.4521427032053978, 0.3217511947862763, 0.2261061020083259]
# Node selected by probability distribution: 39
# Closest Nodes: ['38', '37', '2']
# Normalized distances: [0.9586536694095279, 0.036165776929166386, 0.005180553661305617]
# Node selected by probability distribution: 38
# Closest Nodes: ['37', '2', '10']
# Normalized distances: [0.7215723018299857, 0.14298174089450205, 0.13544595727551217]
# Node selected by probability distribution: 37
# Closest Nodes: ['35', '4', '44']
# Normalized distances: [0.47427017186192016, 0.26390392483779446, 0.2618259033002853]
# Node selected by probability distribution: 44
# Closest Nodes: ['45', '9', '35']
# Normalized distances: [0.9964547068827869, 0.00218033595934033, 0.0013649571578728057]
# Node selected by probability distribution: 9
# Closest Nodes: ['22', '21', '20']
# Normalized distances: [0.3759729344340555, 0.36346743769387313, 0.2605596278720715]
# Node selected by probability distribution: 22
# Closest Nodes: ['21', '1', '25']
# Normalized distances: [0.9950900659400717, 0.0024571619039377643, 0.002452772155990728]
# Node selected by probability distribution: 25
# Closest Nodes: ['1', '10', '16']
# Normalized distances: [0.9999736049106274, 1.3829514441376279e-05, 1.2565574931200119e-05]
# Node selected by probability distribution: 16
# Closest Nodes: ['10', '1', '2']
# Normalized distances: [0.7804560984688766, 0.12197568771051515, 0.09756821382060814]
# Node selected by probability distribution: 10
# Closest Nodes: ['1', '2', '3']
# Normalized distances: [0.6411747660104276, 0.28616962374544186, 0.07265561024413059]
# Node selected by probability distribution: 3
# Closest Nodes: ['2', '17', '1']
# Normalized distances: [0.5028554142159772, 0.40350014885107444, 0.09364443693294842]
# Node selected by probability distribution: 17
# Closest Nodes: ['2', '1', '11']
# Normalized distances: [0.5541864987178687, 0.2672767013226123, 0.17853679995951904]
# Node selected by probability distribution: 1
# Closest Nodes: ['2', '21', '11']
# Normalized distances: [0.6975465357055364, 0.223728958658921, 0.07872450563554259]
# Node selected by probability distribution: 11
# Closest Nodes: ['18', '19', '2']
# Normalized distances: [0.48913127071468177, 0.37761607733176344, 0.13325265195355476]
# Node selected by probability distribution: 2
# Closest Nodes: ['21', '18', '19']
# Normalized distances: [0.49539174279341197, 0.32694217436732287, 0.17766608283926522]
# Node selected by probability distribution: 21
# Closest Nodes: ['20', '26', '18']
# Normalized distances: [0.614509937715894, 0.21236120005558007, 0.17312886222852594]
# Node selected by probability distribution: 20
# Closest Nodes: ['26', '27', '45']
# Normalized distances: [0.7631944657614956, 0.11969838022631916, 0.11710715401218523]
# Node selected by probability distribution: 27
# Closest Nodes: ['23', '24', '26']
# Normalized distances: [0.712940134570611, 0.2851072651817112, 0.0019526002476778247]
# Node selected by probability distribution: 24
# Closest Nodes: ['23', '26', '19']
# Normalized distances: [0.9985865784965707, 0.0011706890679564089, 0.0002427324354729396]
# Node selected by probability distribution: 19
# Closest Nodes: ['18', '12', '13']
# Normalized distances: [0.8111054065956568, 0.12118886661194946, 0.06770572679239378]
# Node selected by probability distribution: 13
# Closest Nodes: ['15', '14', '12']
# Normalized distances: [0.5537309011268946, 0.44301165601020104, 0.003257442862904444]
# Node selected by probability distribution: 15
# Closest Nodes: ['14', '12', '18']
# Normalized distances: [0.9923661077996812, 0.006427261666452468, 0.0012066305338664597]
# Node selected by probability distribution: 18
# Closest Nodes: ['12', '14', '26']
# Normalized distances: [0.486013446730058, 0.3229011853159724, 0.1910853679539696]
# Node selected by probability distribution: 14
# Closest Nodes: ['12', '5', '4']
# Normalized distances: [0.920172928948408, 0.040235731848052944, 0.039591339203539126]
# Node selected by probability distribution: 4
# Closest Nodes: ['5', '36', '8']
# Normalized distances: [0.9855975592639225, 0.010683286639153619, 0.0037191540969239334]
# Node selected by probability distribution: 36
# Closest Nodes: ['5', '8', '35']
# Normalized distances: [0.39490892730223254, 0.35546852773081367, 0.24962254496695369]
# Node selected by probability distribution: 5
# Closest Nodes: ['8', '35', '6']
# Normalized distances: [0.41116022750680425, 0.3358359666283062, 0.25300380586488946]
# Node selected by probability distribution: 6
# Closest Nodes: ['7', '8', '28']
# Normalized distances: [0.966563702654124, 0.028427875135769786, 0.005008422210106259]
# Node selected by probability distribution: 7
# Closest Nodes: ['8', '28', '30']
# Normalized distances: [0.7483027510733707, 0.19808039634493274, 0.05361685258169659]
# Node selected by probability distribution: 8
# Closest Nodes: ['28', '35', '33']
# Normalized distances: [0.4883893879354659, 0.2674193656952103, 0.24419124636932385]
# Node selected by probability distribution: 28
# Closest Nodes: ['30', '34', '33']
# Normalized distances: [0.7061873770117799, 0.1595897995246682, 0.13422282346355188]
# Node selected by probability distribution: 34
# Closest Nodes: ['33', '30', '35']
# Normalized distances: [0.5391523535698562, 0.25169043059460744, 0.20915721583553643]
# Node selected by probability distribution: 30
# Closest Nodes: ['33', '35', '45']
# Normalized distances: [0.5088086344676123, 0.35221970742412484, 0.13897165810826287]
# Node selected by probability distribution: 45
# Closest Nodes: ['35', '33', '26']
# Normalized distances: [0.46247603245709434, 0.4162325960516845, 0.12129137149122114]
# Node selected by probability distribution: 35
# Closest Nodes: ['33', '26', '12']
# Normalized distances: [0.9729706745549439, 0.013985404397547153, 0.013043921047509005]
# Node selected by probability distribution: 33
# Closest Nodes: ['26', '12', '29']
# Normalized distances: [0.3907129765655914, 0.3315357467449053, 0.27775127668950333]
# Node selected by probability distribution: 29
# Closest Nodes: ['26', '23', '12']
# Normalized distances: [0.401544675456969, 0.3495660239028488, 0.2488893006401823]
# Node selected by probability distribution: 12
# Closest Nodes: ['26', '23']
# Normalized distances: [0.6508479473847183, 0.3491520526152816]
# Node selected by probability distribution: 26
# Closest Nodes: ['23']
# Normalized distances: [1.0]
# Node selected by probability distribution: 23
# 25
# -100
# Best fitness obtained:  1017.093
# Improvement over randomized greedy heuristic:  0.0622

# %% [markdown]
# #### Signature
#
# I, Rupsi Kaushik, declare that the answers provided in this notebook are my own.
